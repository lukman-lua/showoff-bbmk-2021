# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
bangunDatar = plt.imread('dangun_datar.jpg', cv2.IMREAD_COLOR)
bangunDatar
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(bangunDatar)

# %%
gray = cv2.cvtColor(bangunDatar, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(gray)

# %%
cv2.imshow('Original image',bangunDatar)
cv2.imshow('Gray image', thresh)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh)

# %%
(contours, hierarchy) = cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(bangunDatar,contours,-1,(0,255,0),3)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12580/3047762549.py in <module>
# ----> 1 (contours, hierarchy) = cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
#       2 cv2.drawContours(bangunDatar,contours,-1,(0,255,0),3)
#       3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined
