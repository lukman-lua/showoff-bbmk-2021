# %%
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as mpimg
import numpy as np
import random as rng

# %%
# %matplotlib inline

# %%
# membaca gambar sebagai matrix
kucing = mpimg.imread('kucuing.jpg')
kucing
# Out:
# array([[[ 64,  61,  26],
#         [ 62,  59,  24],
#         [ 60,  60,  24],
#         ...,
#         [251, 252, 254],
#         [250, 251, 253],
#         [249, 250, 252]],
#
#        [[ 63,  60,  25],
#         [ 63,  60,  25],
#         [ 61,  61,  25],
#         ...,
#         [251, 252, 254],
#         [250, 251, 253],
#         [249, 250, 252]],
#
#        [[ 63,  60,  27],
#         [ 63,  60,  27],
#         [ 63,  60,  25],
#         ...,
#         [252, 252, 254],
#         [251, 251, 251],
#         [250, 250, 250]],
#
#        ...,
#
#        [[ 29,  17,   1],
#         [ 32,  20,   4],
#         [ 31,  19,   3],
#         ...,
#         [184, 183, 189],
#         [182, 181, 186],
#         [180, 179, 184]],
#
#        [[ 29,  17,   1],
#         [ 32,  20,   4],
#         [ 32,  20,   4],
#         ...,
#         [184, 183, 189],
#         [182, 181, 186],
#         [181, 180, 185]],
#
#        [[ 31,  19,   3],
#         [ 34,  22,   6],
#         [ 33,  21,   5],
# ...

# %%
# tampilkan gambar kucing
plt.imshow(kucing)

# %%
img = 0

# %%
x = 150
y = 8
w = 160
h = 180
cv2.rectangle(kucing,(x,y),(x+w,y+h),(255,0,0),2)
# roi_gray = gray[y:y+h, x:x+w]
# roi_color = img[y:y+h, x:x+w]
# eyes = eye_cascade.detectMultiScale(roi_gray)
# for (ex,ey,ew,eh) in eyes:
#     cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
# Out:
# array([[[ 64,  61,  26],
#         [ 62,  59,  24],
#         [ 60,  60,  24],
#         ...,
#         [251, 252, 254],
#         [250, 251, 253],
#         [249, 250, 252]],
#
#        [[ 63,  60,  25],
#         [ 63,  60,  25],
#         [ 61,  61,  25],
#         ...,
#         [251, 252, 254],
#         [250, 251, 253],
#         [249, 250, 252]],
#
#        [[ 63,  60,  27],
#         [ 63,  60,  27],
#         [ 63,  60,  25],
#         ...,
#         [252, 252, 254],
#         [251, 251, 251],
#         [250, 250, 250]],
#
#        ...,
#
#        [[ 29,  17,   1],
#         [ 32,  20,   4],
#         [ 31,  19,   3],
#         ...,
#         [184, 183, 189],
#         [182, 181, 186],
#         [180, 179, 184]],
#
#        [[ 29,  17,   1],
#         [ 32,  20,   4],
#         [ 32,  20,   4],
#         ...,
#         [184, 183, 189],
#         [182, 181, 186],
#         [181, 180, 185]],
#
#        [[ 31,  19,   3],
#         [ 34,  22,   6],
#         [ 33,  21,   5],
# ...

# %%
plt.imshow(kucing)

# %%
coordinat = (215, 115)
radius = 20
color = (0, 152, 217)
thickness = 4
cv2.circle(kucing, coordinat, radius, color, thickness)
# Out:
# array([[[ 64,  61,  26],
#         [ 62,  59,  24],
#         [ 60,  60,  24],
#         ...,
#         [251, 252, 254],
#         [250, 251, 253],
#         [249, 250, 252]],
#
#        [[ 63,  60,  25],
#         [ 63,  60,  25],
#         [ 61,  61,  25],
#         ...,
#         [251, 252, 254],
#         [250, 251, 253],
#         [249, 250, 252]],
#
#        [[ 63,  60,  27],
#         [ 63,  60,  27],
#         [ 63,  60,  25],
#         ...,
#         [252, 252, 254],
#         [251, 251, 251],
#         [250, 250, 250]],
#
#        ...,
#
#        [[ 29,  17,   1],
#         [ 32,  20,   4],
#         [ 31,  19,   3],
#         ...,
#         [184, 183, 189],
#         [182, 181, 186],
#         [180, 179, 184]],
#
#        [[ 29,  17,   1],
#         [ 32,  20,   4],
#         [ 32,  20,   4],
#         ...,
#         [184, 183, 189],
#         [182, 181, 186],
#         [181, 180, 185]],
#
#        [[ 31,  19,   3],
#         [ 34,  22,   6],
#         [ 33,  21,   5],
# ...

# %%
plt.imshow(kucing)

# %%
plt.imsave('kucings.png', kucing)
